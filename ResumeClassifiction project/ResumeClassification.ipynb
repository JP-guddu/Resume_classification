# %% [markdown]
# # Resume Classification
#
# Business objective :- The document classification solution should significantly reduce the manual human effort in the HRM. It should achieve a higher level of accuracy and automation with minimal human intervention

# %%
import os #Used for path
import re #Regex
import csv #text into csv file
from docx import Document #.Docx Convert into text
from PyPDF2 import PdfReader #pdf Convert into text
import win32com.client as win32 #used for open Word file Component Object Model (COM)
from win32com.client import constants
import pandas as pd
import glob

# %% [markdown]
# - Dataset are the form of .pdf,.Docx,.Doc format so,First we convert into text

# %%
def extract_text_from_pdf(file_path): #This function is used for extract text from pdf
    with open(file_path, 'rb') as file:
        reader = PdfReader(file)
        text = ''
        for page in reader.pages:
            text += page.extract_text()
        return text

def extract_text_from_docx(file_path): #This function is used for extract text from Docx
    doc = Document(file_path)
    paragraphs = [p.text for p in doc.paragraphs]
    return '\n'.join(paragraphs)

def save_as_docx(file_path): #If Doc is not readed that this function convert Doc into Docx.by open Docx file and saveAS into Doc
    # Opening MS Word
    word = win32.gencache.EnsureDispatch('Word.Application')
    doc = word.Documents.Open(file_path)
    doc.Activate()

    # Rename path with .docx
    new_file_abs = os.path.abspath(file_path)
    new_file_abs = os.path.splitext(file_path)[0] + '.docx'

    # Save and Close
    word.ActiveDocument.SaveAs(
        new_file_abs, FileFormat=constants.wdFormatXMLDocument
    )
    doc.Close(False)

def clean_text(text):
    cleaned_text = re.sub(r'\s+', ' ', text)  # Remove extra space
    return cleaned_text

# %%
# Database path:
input_directory = r'C:\Users\abc\Desktop\Resume Classification\Resume1'
output_csv = 'Resume_text.csv'

with open(output_csv, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['Text',"Resume"])  # Write header row
    for file_path in glob.glob(os.path.join(input_directory, '**', '*'), recursive=True):
        if not os.path.isfile(file_path):
            continue

        resume = []
        file_name = os.path.basename(file_path)
        folder_path = os.path.dirname(file_path)
        if folder_path.lower().endswith("\\peoplesoft"):
            resume.append('peoplesoft') 
        elif folder_path.lower().endswith("\\workday"):
            resume.append('workday')
        elif folder_path.lower().endswith("\\sql developer"):
            resume.append('sql developer') 
        elif folder_path.lower().endswith("\\react developer"):                                  
            resume.append('react developer')
        #file_path = os.path.join(root, file_name)
        #file_path = os.path.join(input_directory, file_name)
        if file_name.lower().endswith('.pdf'):
            text = extract_text_from_pdf(file_path)
        elif file_name.lower().endswith('.docx'):
            text = extract_text_from_docx(file_path)
        elif file_name.lower().endswith('.doc'):
            save_as_docx(file_path)
            text = extract_text_from_docx(file_path + 'x')
            os.remove(file_path + 'x')  # Remove the temporary .docx file
        else:
            print(f"Skipping file: {file_name}. Unsupported file format.")
            continue
        
        cleaned_text = clean_text(text)
        writer.writerow([cleaned_text]+resume)

print("Extraction and cleaning complete. Saved to Resume_text.csv.")
# Out:
# Extraction and cleaning complete. Saved to Resume_text.csv.

# %% [markdown]
# # Spacy Library
# - For NLP tasks we use Spacy library. Using of spacy we can perform Part-of-Speech Tagging, Dependency Parsing and Named Entity Recognition.

# %%
import spacy 
nlp = spacy.load('en_core_web_md') #loading spacy pre built model
from spacy.matcher import Matcher

# %%
df = pd.read_csv('Resume_text.csv')  # uploading csv file

# %%
df
# Out:
#                                                  Text      Resume
# 0    Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1    Profile Summary: 7+ years of experience in im...  peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
# ..                                                ...         ...
# 74   Workday Integration Consultant Name : Sri Kri...     workday
# 75  Seeking suitable positions in Workday HCM as T...     workday
# 76   WORKDAY | HCM | FCM Name : Kumar S.S Role : W...     workday
# 77  Venkateswarlu.B Workday Consultant Having 5.3 ...     workday
# 78   Vinay kumar .v Workday Functional Consultant ...     workday
#
# [79 rows x 2 columns]

# %%
df["Text"][5]
# Out:
# " PROFILE SUMMARY I have overall 6.8 years’ experience as PeopleSoft Administrator. Installed PeopleTools 8.55 from the scratch including its products. Experience in Peopletools 8.51, 8.54.08, 8.55.07&Application 9.0 and 9.2 (HRMS/FSCM). Deterministic approach towards problem solving & troubleshooting. Proficient in Integration Broker. Upgraded FSCM and HCM applications to PeopleTools 8.55.07 from PeopleTools 8.54.08. EDUCATION Graduated B-Tech in Electronics and Communication Engg. from M.V.G.R College of Engineering, Vizianagaram(JNTUK) with an aggregate of 68.93%. Achieved 90% marks in 12th standard. Scored 86% in 10th standard. ACHIEVEMENTS Awarded Bravo in 2015 Q3, 2016 Q1 and Pat on Back in Q2, 2016, Q1, 2017 in Techahindra. Awarded Associate of the month award and Innovator of the month (1 time). Awarded spot and pat on back in Capgemini WORK EXPERIENCE CAPGEMINI (MAY’19 – TILL NOW) Production support for 5 finance environment and their respective non production environments. Project Experience: Project Name : AXA Role : Consultant Environment : Windows Server 2012 R2 COGNIZANT TECHNOL OGY SOL UT IONS (AUGUS T ' 1 8 – APRIL’19) Voya Financial Insurance US client project which deals with support and managing Finance applications. Project Experience: Project Name : Voya Financials Role : Associate Environment : Windows Server 2012 R2 TECH MAHINDRA LIMIT ED (JULY ' 1 4 - AUGUS T ' 18) PeopleSoft 9.2 Implemented for HR and FIN application. PeopleSoft 9.2 Implementation project includes 10 PeopleSoft applications, interfaces with third-party applications and interfaces with live production PeopleSoft 9.2 environment in SDLC. Project Experience: Project Name Role Environment : CIO COMMON : Software Engineer : SOLARIS, Windows Server 2008R2 RESPONSIBILITIES: Provided administrative supports for PEOPLESOFT tools version 8.51, 8.54, 8.55.25, 8.56.10 and application HRMS 9.0, 9.2 & Financials/SCM 9.0, 9.2 modules on Windows and UNIX OS Creation of indexes for tables from application designer. PeopleSoft Database Setup, troubleshooting issues and other daily PeopleSoft admin activities Configured PeopleSoft application server, process scheduler & web server domains, setup Master Scheduler. Installing Oracle Tuxedo, Weblogic, Java, Application Disk (FSCM and HCM) and Oracle database on UNIX and Windows servers from scratch Installed PeopleTools 8.55 for HCM and FSCM with a demo database. Upgraded FSCM application to Peopletools 8.55 from PeopleTools 8.54.08. Applied patch 8.55.07 in FSCM Configured Report Nodes. Bouncing of App, Web and Process schedulers and clearing cache Performed pre-refresh and post refresh activity during Database cloning activity. Recompilation of COBOL source codes Worked on project migrations using Application Designer and Change Assistant. Applied image 15, 16, 25 and 37 on FSCM 9.2 using PUM and change assistant. Good hands-on experience in application designer, data mover, and change assistant. Well aware of PIA (PeopleSoft Internet Architecture). Configuring Integration broker and report nodes Creating UDM file transfer Interfaces and monitoring them Deploying gnupg keys and certificates in servers. Installed and configured Elastic search. TOOLS USED: PeopleTools 8.54.08, 8.56.10, 8.55.25, Application Designer, Data Mover Toad, Sqldeveloper, Microsoft SQL Management Studio 2014 Oracle 11g, Oracle 12c, Microsoft SQL server 2014 Filezilla, Winscp, PCOMM, TWS, Service now, Silva TRAINING & CERTIFICATIONS Oracle Cloud Infrastructure Architect Associate Oracle Cloud Infrastructure Architect Professional "

# %% [markdown]
# # Extracting skills

# %%
def extract_skills(resume_text):
    nlp_text = nlp(resume_text)

    # removing stop words and implementing word tokenization
    tokens = [token.text for token in nlp_text if not token.is_stop]
    # Set of skills if skills match with this text than they append in skills column
    skills = ["c","my sql","nodejs","node.js","reactjs","javascript","html","css","javascript","angular js",
              "js","fcsm","sql developer","peopleSoft","mysql","sql","plsql","nosql","rdbms","ddl" ,"dml","dcl"
              ,"sql developer","core hcm","xml", "xslt", "eib", "core connectors","workday",'hcm',"peoplesoft admin",
               "PeopleSoft Admin","dba","" ]
    
    skillset = []
    
    # check for one-grams (example: python)
    for token in tokens:
        if token.lower() in skills:
            skillset.append(token)
    
    #check for bi-grams and tri-grams (example: machine learning)
    for token in nlp_text.noun_chunks:
        token = token.text.lower().strip()
        if token in skills:
            skillset.append(token)
    
  
    return ', '.join(set([i.capitalize() for i in skillset]))

# %%
df["skills"] = df['Text'].apply(extract_skills)

# %%
df.head()
# Out:
#                                                 Text      Resume  \
# 0   Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1   Profile Summary: 7+ years of experience in im...  peoplesoft
# 2  PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3  Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4  Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
#
#              skills
# 0               Hcm
# 1          Dba, Hcm
# 2     Dba, Hcm, Sql
# 3               Hcm
# 4  Peoplesoft admin

# %% [markdown]
# # Name Extraction

# %%
# In name extraction we use POS tagging. 
matcher = Matcher(nlp.vocab) 

def extract_name(resume_text):
    nlp_text = nlp(resume_text)
    
    # First name and Last name are always Proper Nouns
    pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
    
    matcher.add('NAME', [pattern], on_match = None)
    
    matches = matcher(nlp_text)
    
    for match_id, start, end in matches:
        span = nlp_text[start:end]
        return span.text

# %%
df["Name"] = df['Text'].apply(extract_name)

# %%
df.sample(10)
# Out:
#                                                  Text           Resume  \
# 9    PeopleSoft Admin/PeopleSoft DBA Ganesh Alladi...       peoplesoft
# 47  KAMBALLA PRADEEP SYNOPSIS Looking forward to a...    sql developer
# 26   PROFILE Searching for the opportunity to brin...  react developer
# 66   Madeeswar A PROFILE SUMMARY: Having around 6 ...          workday
# 31   Ui-Developer/ React JS Developer NAME: KRISHN...  react developer
# 61  Harikrishna Akula Summary: 5.2 years of IT exp...          workday
# 5    PROFILE SUMMARY I have overall 6.8 years’ exp...       peoplesoft
# 45   Aradhana Tripathi Current Location: Gachibowl...    sql developer
# 6   PEOPLESOFT Administrator SRINIVAS.K Experience...       peoplesoft
# 32   Ui-Developer/ React JS Developer NAME: KRISHN...  react developer
#
#                                                skills  \
# 9                          Dba, Hcm, Peoplesoft admin
# 47                          Rdbms, Ddl, Dml, Dcl, Sql
# 26              Html, Css, Javascript, Mysql, Node.js
# 66      Xml, Hcm, Workday, Eib, Xslt, Core connectors
# 31            Html, Js, Css, Xml, Javascript, Node.js
# 61  Xml, Hcm, Workday, Eib, Sql, Xslt, Core connec...
# 5                                            Hcm, Sql
# 45                               Mysql, Dml, Ddl, Sql
# 6                                       Dba, Hcm, Sql
# 32            Html, Js, Css, Xml, Javascript, Node.js
#
#                         Name
# 9           PeopleSoft Admin
# 47          KAMBALLA PRADEEP
# 26               CORE SKILLS
# 66               Madeeswar A
# 31          Developer/ React
# 61         Harikrishna Akula
# 5   PeopleSoft Administrator
# 45         Aradhana Tripathi
# 6   PEOPLESOFT Administrator
# 32          Developer/ React

# %% [markdown]
# # Previous company Experiences

# %%
nlp = spacy.load('en_core_web_lg')

def extract_experiences(text): #Extract Experience from resume
    doc = nlp(text)

    experiences = []
    for sent in doc.sents:
        if 'experience' in sent.text.lower():
            experiences.append(sent.text)

    return ', '.join(set(i for i in experiences))

# %%
df["experience"] = df["Text"].apply(extract_experiences)

# %%
df
# Out:
#                                                  Text      Resume  \
# 0    Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1    Profile Summary: 7+ years of experience in im...  peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
# ..                                                ...         ...
# 74   Workday Integration Consultant Name : Sri Kri...     workday
# 75  Seeking suitable positions in Workday HCM as T...     workday
# 76   WORKDAY | HCM | FCM Name : Kumar S.S Role : W...     workday
# 77  Venkateswarlu.B Workday Consultant Having 5.3 ...     workday
# 78   Vinay kumar .v Workday Functional Consultant ...     workday
#
#                                                skills  \
# 0                                                 Hcm
# 1                                            Dba, Hcm
# 2                                       Dba, Hcm, Sql
# 3                                                 Hcm
# 4                                    Peoplesoft admin
# ..                                                ...
# 74      Xml, Hcm, Workday, Eib, Xslt, Core connectors
# 75  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 76  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 77                       Xml, Hcm, Workday, Eib, Xslt
# 78                       Xml, Hcm, Workday, Eib, Xslt
#
#                          Name  \
# 0               Anubhav Kumar
# 1               Human Capital
# 2         PeopleSoft Database
# 3   PeopleSoft Administration
# 4           Priyanka Ramadoss
# ..                        ...
# 74        Workday Integration
# 75                Workday HCM
# 76                  Kumar S.S
# 77                  B Workday
# 78                Vinay kumar
#
#                                            experience
# 0   Experience in Installing Oracle Policy Automat...
# 1   Skilled with the capability to analyse & inter...
# 2   Experience in monitoring and scheduling Jobs.,...
# 3   Experience in Configuration and Setup the REN ...
# 4   Experienced in setting up batch profile setup ...
# ..                                                ...
# 74  Hands-on experience In Migrating the XSLT Code...
# 75  Having good experience in building Studio inbo...
# 76  Hands-on experience In Migrating the XSLT Code...
# 77  Strong experience in building Workday Studio i...
# 78  Experience in implementing Workday Functional ...
#
# [79 rows x 5 columns]

# %% [markdown]
# # Education

# %%
def ed(text):  #Extract Education from Resume
    doc = nlp(text)

    edu = []
    for sent in doc.sents:
        if ("educational qualification" and 'education') in sent.text.lower():
            edu.append(sent.text)
    return ', '.join(set(i for i in edu))

# %%
df["Education"] = df["Text"].apply(ed)

# %%
df
# Out:
#                                                  Text      Resume  \
# 0    Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1    Profile Summary: 7+ years of experience in im...  peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
# ..                                                ...         ...
# 74   Workday Integration Consultant Name : Sri Kri...     workday
# 75  Seeking suitable positions in Workday HCM as T...     workday
# 76   WORKDAY | HCM | FCM Name : Kumar S.S Role : W...     workday
# 77  Venkateswarlu.B Workday Consultant Having 5.3 ...     workday
# 78   Vinay kumar .v Workday Functional Consultant ...     workday
#
#                                                skills  \
# 0                                                 Hcm
# 1                                            Dba, Hcm
# 2                                       Dba, Hcm, Sql
# 3                                                 Hcm
# 4                                    Peoplesoft admin
# ..                                                ...
# 74      Xml, Hcm, Workday, Eib, Xslt, Core connectors
# 75  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 76  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 77                       Xml, Hcm, Workday, Eib, Xslt
# 78                       Xml, Hcm, Workday, Eib, Xslt
#
#                          Name  \
# 0               Anubhav Kumar
# 1               Human Capital
# 2         PeopleSoft Database
# 3   PeopleSoft Administration
# 4           Priyanka Ramadoss
# ..                        ...
# 74        Workday Integration
# 75                Workday HCM
# 76                  Kumar S.S
# 77                  B Workday
# 78                Vinay kumar
#
#                                            experience  \
# 0   Experience in Installing Oracle Policy Automat...
# 1   Skilled with the capability to analyse & inter...
# 2   Experience in monitoring and scheduling Jobs.,...
# 3   Experience in Configuration and Setup the REN ...
# 4   Experienced in setting up batch profile setup ...
# ..                                                ...
# 74  Hands-on experience In Migrating the XSLT Code...
# 75  Having good experience in building Studio inbo...
# 76  Hands-on experience In Migrating the XSLT Code...
# 77  Strong experience in building Workday Studio i...
# 78  Experience in implementing Workday Functional ...
#
#                                             Education
# 0
# 1   ǁ Education: Bachelors in Computer Science Ani...
# 2
# 3
# 4                  Present Education Personal Profile
# ..                                                ...
# 74  Education details: Bachelors in Electronics & ...
# 75
# 76  Educational Summary: M.Tech in computer scienc...
# 77
# 78  EDUCATION SUMMARY Master of business administr...
#
# [79 rows x 6 columns]

# %%
df.head(50)
# Out:
#                                                  Text           Resume  \
# 0    Anubhav Kumar Singh To work in a globally com...       peoplesoft
# 1    Profile Summary: 7+ years of experience in im...       peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...       peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...       peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...       peoplesoft
# 5    PROFILE SUMMARY I have overall 6.8 years’ exp...       peoplesoft
# 6   PEOPLESOFT Administrator SRINIVAS.K Experience...       peoplesoft
# 7    PeopleSoft Admin VARKALA VIKAS Career Objecti...       peoplesoft
# 8   Vinod Akkala PeopleSoft DBA Admin. Professiona...       peoplesoft
# 9    PeopleSoft Admin/PeopleSoft DBA Ganesh Alladi...       peoplesoft
# 10  PeopleSoft Administration Vivekanand Sayana Ca...       peoplesoft
# 11  Arun Venu EXPERIENCE SUMMARY Experience of 04 ...       peoplesoft
# 12   Experience Summary 4.1 years- Experience of D...       peoplesoft
# 13  Rahul Ahuja ----------------------------------...       peoplesoft
# 14   Having 4.6 years of experience in PeopleSoft ...       peoplesoft
# 15   Having 4.6 years of experience in PeopleSoft ...       peoplesoft
# 16   CAREER OBJECTIVE Pursuing Peoplesoft Executiv...       peoplesoft
# 17   R Ahmed PeopleSoft Technical Consultant PROFE...       peoplesoft
# 18  Tanna Sujatha OBJECTIVE Seeking a challenging ...       peoplesoft
# 19   C O N T A C T : Address: Manyata Tech Park, N...       peoplesoft
# 20  Name: Ravali P Curriculum Vitae Specialization...  react developer
# 21   SUSOVAN BAG Seeking a challenging position in...  react developer
# 22  Kanumuru Deepak Reddy CAREER OBJECTIVE: To sec...  react developer
# 23  HARIPRIYA BATTINA Experience as UI Developer i...  react developer
# 24  KAMALAKAR REDDY. A Linked In: https://www.link...  react developer
# 25   Naveen Sadhu Title: software developer Locati...  react developer
# 26   PROFILE Searching for the opportunity to brin...  react developer
# 27   PRAGNYA PATTNAIK Expertise: Having around 2 y...  react developer
# 28    204,Sri geethika prestige,road number 10,ba...  react developer
# 29   Thirupathamma Balla SUMMARY: 2.8 year of IT e...  react developer
# 30  Maryala Vinay Reddy Professional Summary: Havi...  react developer
# 31   Ui-Developer/ React JS Developer NAME: KRISHN...  react developer
# 32   Ui-Developer/ React JS Developer NAME: KRISHN...  react developer
# 33  CURRICULUM VITAE I hereby declare that the abo...  react developer
# 34  Kotani Durga Prasad Objective: Aspirant for a ...  react developer
# 35  Venkatalakshmi Pedireddy Software Developer Ex...  react developer
# 36  KAMBALA SAI SURENDRA Mandepeta SUMMARY Project...  react developer
# 37  MAREEDU LOKESH BABU PROFESSIONAL OVERVIEW Arou...  react developer
# 38  MAREEDU LOKESH BABU PROFESSIONAL OVERVIEW Arou...  react developer
# 39  MD KHIZARUDDIN RAUF EXPERIENCE ⇨ Currently wor...  react developer
# 40   Page | 1 Name: M. Prabakaran Title: UI Develo...  react developer
# 41   Pranish Sonone Career summary: Experience of ...  react developer
# 42  Ranga Gaganam Having 1+ years of successful IT...  react developer
# 43  SHAIK ABDUL SHARUK 2 years’ Experience in Wipr...  react developer
# 44  ANIL KUMAR MADDUKURI SQL & MSBI Developer Summ...    sql developer
# 45   Aradhana Tripathi Current Location: Gachibowl...    sql developer
# 46  BUDDHA VAMSI CAREER OBJECTIVE: Have 2.11 years...    sql developer
# 47  KAMBALLA PRADEEP SYNOPSIS Looking forward to a...    sql developer
# 48    Hyderabad Nazeer Basha SQL and Power BI Dev...    sql developer
# 49   Resume Name : Neeraj Mishra Having 3 year 6 M...    sql developer
#
#                                                skills  \
# 0                                                 Hcm
# 1                                            Dba, Hcm
# 2                                       Dba, Hcm, Sql
# 3                                                 Hcm
# 4                                    Peoplesoft admin
# 5                                            Hcm, Sql
# 6                                       Dba, Hcm, Sql
# 7                          Dba, Hcm, Peoplesoft admin
# 8                                            Dba, Hcm
# 9                          Dba, Hcm, Peoplesoft admin
# 10                                           Dba, Hcm
# 11                                                Hcm
# 12                                        C, Hcm, Sql
# 13                                                Xml
# 14                                                Hcm
# 15                                                Hcm
# 16                                                Sql
# 17                                                Xml
# 18                                                Sql
# 19                                             C, Sql
# 20
# 21                      Html, C, Css, Javascript, Sql
# 22                 Html, Js, Css, Javascript, Reactjs
# 23  Html, Js, C, Css, Javascript, Reactjs, Mysql, Sql
# 24                 Html, Js, Css, Javascript, Reactjs
# 25                    Html, Css, Nodejs, Reactjs, Sql
# 26              Html, Css, Javascript, Mysql, Node.js
# 27                                Javascript, Css, Js
# 28                          Html, Javascript, Css, Js
# 29                                         Javascript
# 30                      Html, Javascript, Js, Reactjs
# 31            Html, Js, Css, Xml, Javascript, Node.js
# 32            Html, Js, Css, Xml, Javascript, Node.js
# 33
# 34                               Html, Javascript, Js
# 35                              Angular js, Mysql, Js
# 36                          Html, Javascript, Css, Js
# 37                   Html, Js, Css, Javascript, Mysql
# 38                   Html, Js, Css, Javascript, Mysql
# 39                   Html, Js, Css, Javascript, Mysql
# 40                        Html, Js, Css, Xml, Reactjs
# 41                       Javascript, Css, Js, Reactjs
# 42                      Html, Javascript, Js, Reactjs
# 43                                                 Js
# 44                                         Rdbms, Sql
# 45                               Mysql, Dml, Ddl, Sql
# 46                                         Plsql, Sql
# 47                          Rdbms, Ddl, Dml, Dcl, Sql
# 48                                      Ddl, Dml, Sql
# 49           Plsql, Sql developer, Ddl, Dba, Dml, Sql
#
#                          Name  \
# 0               Anubhav Kumar
# 1               Human Capital
# 2         PeopleSoft Database
# 3   PeopleSoft Administration
# 4           Priyanka Ramadoss
# 5    PeopleSoft Administrator
# 6    PEOPLESOFT Administrator
# 7            PeopleSoft Admin
# 8                Vinod Akkala
# 9            PeopleSoft Admin
# 10  PeopleSoft Administration
# 11                  Arun Venu
# 12         PeopleSoft Project
# 13                Rahul Ahuja
# 14          FSCM Applications
# 15          FSCM Applications
# 16       Peoplesoft Executive
# 17                    R Ahmed
# 18              Tanna Sujatha
# 19               Manyata Tech
# 20                   Ravali P
# 21                SUSOVAN BAG
# 22            Kanumuru Deepak
# 23          HARIPRIYA BATTINA
# 24            KAMALAKAR REDDY
# 25               Naveen Sadhu
# 26                CORE SKILLS
# 27           PRAGNYA PATTNAIK
# 28                   React Js
# 29        Thirupathamma Balla
# 30              Maryala Vinay
# 31           Developer/ React
# 32           Developer/ React
# 33       Anjani Priyadarshini
# 34               Kotani Durga
# 35   Venkatalakshmi Pedireddy
# 36                KAMBALA SAI
# 37             MAREEDU LOKESH
# 38             MAREEDU LOKESH
# 39             MD KHIZARUDDIN
# 40              M. Prabakaran
# 41             Pranish Sonone
# 42              Ranga Gaganam
# 43                SHAIK ABDUL
# 44                 ANIL KUMAR
# 45          Aradhana Tripathi
# 46          Database Engineer
# 47           KAMBALLA PRADEEP
# 48                 Hyderabad
# 49              Neeraj Mishra
#
#                                            experience  \
# 0   Experience in Installing Oracle Policy Automat...
# 1   Skilled with the capability to analyse & inter...
# 2   Experience in monitoring and scheduling Jobs.,...
# 3   Experience in Configuration and Setup the REN ...
# 4   Experienced in setting up batch profile setup ...
# 5   Experience in Peopletools 8.51, 8.54.08, 8.55....
# 6   Experience in online and offline cloning for t...
# 7   Experience in Installing COBOL Software and co...
# 8   Experience on People Tools Upgrade., Experienc...
# 9   Experience in standalone RAC., Experience in I...
# 10  In Depth Experience in Integration Broker Trou...
# 11  SOFTWARE PROFICIENCY WORKING EXPERIENCE Curren...
# 12  Technical knowledge and hands on experience in...
# 13  Experience in Implementation of projects., Rep...
# 14  Well experienced on People tools and having Fu...
# 15  Well experienced on People tools and having Fu...
# 16   CAREER OBJECTIVE Pursuing Peoplesoft Executiv...
# 17  Having 3.2 years of Experience as PeopleSoft C...
# 18  Functional Expertise in the below PeopleSoft F...
# 19  I am having more than 3.2 years of experience ...
# 20
# 21
# 22  Good experience in developing draggable grid l...
# 23  OBJECTIVE ● Looking for a challenging role to ...
# 24  A Linked In: https://www.linkedin.com/in/kamal...
# 25   Naveen Sadhu Title: software developer Locati...
# 26   PROFILE Searching for the opportunity to brin...
# 27  Professional Experiences: Project 1: Project D...
# 28  Having 3 years of experience in developing UI-...
# 29  Brief Profile Summary of Skills & Experience W...
# 30  Professional Experience: Experience in design ...
# 31  I have experience as React JS Developer with 3...
# 32  I have experience as React JS Developer with 3...
# 33
# 34  Where HTML5 functionality is not supported by ...
# 35  India WORK EXPERIENCE Developer Schemax Expert...
# 36       IDE EXPERIENCE: Visual Studio Code (VSCODE).
# 37  Around 2 years of experience in software desig...
# 38  Around 2 years of experience in software desig...
# 39  MD KHIZARUDDIN RAUF EXPERIENCE ⇨ Currently wor...
# 40  ● Hands on experience with customization over ...
# 41  Work experience: Currently working with Saffir...
# 42  Experience in design and configuration for imp...
# 43  Experience in Wipro Career Objective: A challe...
# 44  Professional Experience Currently working as S...
# 45  Experience in using sub-queries and joins to s...
# 46  BUDDHA VAMSI CAREER OBJECTIVE: Have 2.11 years...
# 47  Experienced in authoring and deploying SQL Ser...
# 48  Good experience in Power BI Data Modelling by ...
# 49  Experience in Creation of Tables, Indexes usin...
#
#                                             Education
# 0
# 1   ǁ Education: Bachelors in Computer Science Ani...
# 2
# 3
# 4                  Present Education Personal Profile
# 5   EDUCATION Graduated B-Tech in Electronics and ...
# 6
# 7   Good team player and a proven individual contr...
# 8   KEY SKILS EDUCATIONAL QUALIFICATION M.ca.(Mast...
# 9   Good team player and a proven individual contr...
# 10  Strong communication, collaboration, team buil...
# 11  EDUCATIONAL QUALIFICATION BCA (COMPUTER APPLIC...
# 12  Can adopt any hazardous Situations Educational...
# 13  Educational Qualifications: Bachelor of Engine...
# 14
# 15
# 16  Peoplecode TOOLS: People Tools, ORACLE SQL Dev...
# 17  EDUCATIONAL PROFILE B.SC(Computers) with MBA ,...
# 18  EDUCATION BTECH from KAUSHIK COLLEGE OF ENGINE...
# 19
# 20
# 21  EDUCATION BACKGROUND Lovely Professional Unive...
# 22
# 23                       WORK EXPERIENCE EDUCATION 1.
# 24  This project digitalize and animates the educa...
# 25  Education Bachelor of Technology in Computer S...
# 26  EDUCATION GRADUATE APTITUDE TEST IN ENGINEERIN...
# 27             Technical Skills: Educational Profile:
# 28
# 29  Education Project Details Responsibilities : R...
# 30  Educational Profile: Jawaharlal Nehru Technolo...
# 31
# 32
# 33
# 34  Education Details: B.Tech (Computer Science En...
# 35  India WORK EXPERIENCE Developer Schemax Expert...
# 36  Project#2 EDUCATION JNTU, KAKINADA 2015 – 2018...
# 37
# 38
# 39                                  EDUCATION 12/2020
# 40  EDUCATION ● Completed on 2017 Bachelor of Tech...
# 41  Involved in designing website by using CSS and...
# 42
# 43
# 44  Education B.Tech - Velagapudi siddhartha engin...
# 45
# 46
# 47  Education Details Graduated in B.sc from Sri V...
# 48  EDUCATION Jawaharlal Nehru Technological Unive...
# 49

# %% [markdown]
# # Extract Links

# %%
import re

def extract_website_links(text):
    # Regular expression pattern to match website links
    pattern = r'(https?://\S+)'

    # Find all matches using the pattern
    matches = re.findall(pattern, text)

    return ", ".join(matches)

# %%
text = df["Text"][24]

# %%
extract_website_links(text)
# Out:
# 'https://www.linkedin.com/in/kamalakar-reddy-777682196/, http://demo.fortunapix.com/kkel/'

# %%
df["Link"] = df["Text"].apply(extract_website_links)

# %%
df
# Out:
#                                                  Text      Resume  \
# 0    Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1    Profile Summary: 7+ years of experience in im...  peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
# ..                                                ...         ...
# 74   Workday Integration Consultant Name : Sri Kri...     workday
# 75  Seeking suitable positions in Workday HCM as T...     workday
# 76   WORKDAY | HCM | FCM Name : Kumar S.S Role : W...     workday
# 77  Venkateswarlu.B Workday Consultant Having 5.3 ...     workday
# 78   Vinay kumar .v Workday Functional Consultant ...     workday
#
#                                                skills  \
# 0                                                 Hcm
# 1                                            Dba, Hcm
# 2                                       Dba, Hcm, Sql
# 3                                                 Hcm
# 4                                    Peoplesoft admin
# ..                                                ...
# 74      Xml, Hcm, Workday, Eib, Xslt, Core connectors
# 75  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 76  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 77                       Xml, Hcm, Workday, Eib, Xslt
# 78                       Xml, Hcm, Workday, Eib, Xslt
#
#                          Name  \
# 0               Anubhav Kumar
# 1               Human Capital
# 2         PeopleSoft Database
# 3   PeopleSoft Administration
# 4           Priyanka Ramadoss
# ..                        ...
# 74        Workday Integration
# 75                Workday HCM
# 76                  Kumar S.S
# 77                  B Workday
# 78                Vinay kumar
#
#                                            experience  \
# 0   Experience in Installing Oracle Policy Automat...
# 1   Skilled with the capability to analyse & inter...
# 2   Experience in monitoring and scheduling Jobs.,...
# 3   Experience in Configuration and Setup the REN ...
# 4   Experienced in setting up batch profile setup ...
# ..                                                ...
# 74  Hands-on experience In Migrating the XSLT Code...
# 75  Having good experience in building Studio inbo...
# 76  Hands-on experience In Migrating the XSLT Code...
# 77  Strong experience in building Workday Studio i...
# 78  Experience in implementing Workday Functional ...
#
#                                             Education Link
# 0
# 1   ǁ Education: Bachelors in Computer Science Ani...
# 2
# 3
# 4                  Present Education Personal Profile
# ..                                                ...  ...
# 74  Education details: Bachelors in Electronics & ...
# 75
# 76  Educational Summary: M.Tech in computer scienc...
# 77
# 78  EDUCATION SUMMARY Master of business administr...
#
# [79 rows x 7 columns]

# %% [markdown]
# # Extract phone number

# %%
def extract_phone_numbers(text):
    # Regular expression pattern to match phone numbers
    pattern = r'(?<!\d)(?:(?:\d{2}[-\s]?\d{8})|(?:\d{4}[-\s]?\d{6}))(?!\d)'

    # Find all matches using the pattern
    matches = re.findall(pattern, text)

    return ", ".join(matches)

# %%
#Example
number = "Phone number : 91 1234567890"
extract_phone_numbers(number)
# Out:
# '1234567890'

# %%
df["Phone_Number"] = df["Text"].apply(extract_phone_numbers)

# %%
df
# Out:
#                                                  Text      Resume  \
# 0    Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1    Profile Summary: 7+ years of experience in im...  peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
# ..                                                ...         ...
# 74   Workday Integration Consultant Name : Sri Kri...     workday
# 75  Seeking suitable positions in Workday HCM as T...     workday
# 76   WORKDAY | HCM | FCM Name : Kumar S.S Role : W...     workday
# 77  Venkateswarlu.B Workday Consultant Having 5.3 ...     workday
# 78   Vinay kumar .v Workday Functional Consultant ...     workday
#
#                                                skills  \
# 0                                                 Hcm
# 1                                            Dba, Hcm
# 2                                       Dba, Hcm, Sql
# 3                                                 Hcm
# 4                                    Peoplesoft admin
# ..                                                ...
# 74      Xml, Hcm, Workday, Eib, Xslt, Core connectors
# 75  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 76  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 77                       Xml, Hcm, Workday, Eib, Xslt
# 78                       Xml, Hcm, Workday, Eib, Xslt
#
#                          Name  \
# 0               Anubhav Kumar
# 1               Human Capital
# 2         PeopleSoft Database
# 3   PeopleSoft Administration
# 4           Priyanka Ramadoss
# ..                        ...
# 74        Workday Integration
# 75                Workday HCM
# 76                  Kumar S.S
# 77                  B Workday
# 78                Vinay kumar
#
#                                            experience  \
# 0   Experience in Installing Oracle Policy Automat...
# 1   Skilled with the capability to analyse & inter...
# 2   Experience in monitoring and scheduling Jobs.,...
# 3   Experience in Configuration and Setup the REN ...
# 4   Experienced in setting up batch profile setup ...
# ..                                                ...
# 74  Hands-on experience In Migrating the XSLT Code...
# 75  Having good experience in building Studio inbo...
# 76  Hands-on experience In Migrating the XSLT Code...
# 77  Strong experience in building Workday Studio i...
# 78  Experience in implementing Workday Functional ...
#
#                                             Education Link Phone_Number
# 0
# 1   ǁ Education: Bachelors in Computer Science Ani...
# 2
# 3
# 4                  Present Education Personal Profile
# ..                                                ...  ...          ...
# 74  Education details: Bachelors in Electronics & ...
# 75
# 76  Educational Summary: M.Tech in computer scienc...
# 77
# 78  EDUCATION SUMMARY Master of business administr...
#
# [79 rows x 8 columns]

# %% [markdown]
# # Experience in Year

# %%
def expDetails(Text):  #Extract experience in year from Resumes
    global sent
   
    Text = Text.split()
   
    for i in range(len(Text)-2):
        Text[i].lower()
        
        if Text[i] ==  'years':
            sent =  Text[i-2] + ' ' + Text[i-1] +' ' + Text[i] +' '+ Text[i+1] +' ' + Text[i+2]
            l = re.findall('\d*\.?\d+',sent)
            for i in l:
                a = float(i)
            return(a)
            return (sent)

# %%
df["YearExp"] = df["Text"].apply(expDetails)

# %%
df
# Out:
#                                                  Text      Resume  \
# 0    Anubhav Kumar Singh To work in a globally com...  peoplesoft
# 1    Profile Summary: 7+ years of experience in im...  peoplesoft
# 2   PeopleSoft Database Administrator Gangareddy P...  peoplesoft
# 3   Murali Experience Summary I have 6 years of ex...  peoplesoft
# 4   Priyanka Ramadoss 61/46, MountPleasant, Coonoo...  peoplesoft
# ..                                                ...         ...
# 74   Workday Integration Consultant Name : Sri Kri...     workday
# 75  Seeking suitable positions in Workday HCM as T...     workday
# 76   WORKDAY | HCM | FCM Name : Kumar S.S Role : W...     workday
# 77  Venkateswarlu.B Workday Consultant Having 5.3 ...     workday
# 78   Vinay kumar .v Workday Functional Consultant ...     workday
#
#                                                skills  \
# 0                                                 Hcm
# 1                                            Dba, Hcm
# 2                                       Dba, Hcm, Sql
# 3                                                 Hcm
# 4                                    Peoplesoft admin
# ..                                                ...
# 74      Xml, Hcm, Workday, Eib, Xslt, Core connectors
# 75  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 76  Xml, Hcm, Core connectors, Workday, Eib, Xslt,...
# 77                       Xml, Hcm, Workday, Eib, Xslt
# 78                       Xml, Hcm, Workday, Eib, Xslt
#
#                          Name  \
# 0               Anubhav Kumar
# 1               Human Capital
# 2         PeopleSoft Database
# 3   PeopleSoft Administration
# 4           Priyanka Ramadoss
# ..                        ...
# 74        Workday Integration
# 75                Workday HCM
# 76                  Kumar S.S
# 77                  B Workday
# 78                Vinay kumar
#
#                                            experience  \
# 0   Experience in Installing Oracle Policy Automat...
# 1   Skilled with the capability to analyse & inter...
# 2   Experience in monitoring and scheduling Jobs.,...
# 3   Experience in Configuration and Setup the REN ...
# 4   Experienced in setting up batch profile setup ...
# ..                                                ...
# 74  Hands-on experience In Migrating the XSLT Code...
# 75  Having good experience in building Studio inbo...
# 76  Hands-on experience In Migrating the XSLT Code...
# 77  Strong experience in building Workday Studio i...
# 78  Experience in implementing Workday Functional ...
#
#                                             Education Link Phone_Number  \
# 0
# 1   ǁ Education: Bachelors in Computer Science Ani...
# 2
# 3
# 4                  Present Education Personal Profile
# ..                                                ...  ...          ...
# 74  Education details: Bachelors in Electronics & ...
# 75
# 76  Educational Summary: M.Tech in computer scienc...
# 77
# 78  EDUCATION SUMMARY Master of business administr...
#
#     YearExp
# 0       NaN
# 1       7.0
# 2       4.0
# 3       6.0
# 4    2016.0
# ..      ...
# 74      4.0
# 75      4.0
# 76      6.0
# 77      5.3
# 78      4.2
#
# [79 rows x 9 columns]

# %% [markdown]
# - there same null value in columns like Education, link , phone So,drop that columns

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined
